# %%
import pandas as pd
import yfinance as yf
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Valid Time Periods: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max

data_ticker = yf.download("AMD", period="5y")
# data_corr = yf.download("NVDA", period="5y")
data_industry = yf.download("^SOX", period="5y")
# data_SP500 = yf.download("SPY", period="5y")
# data_QQQ = yf.download("QQQ", period="5y")


data_ticker["Percent Change"] = data_ticker["Close"].pct_change() * 100
data_ticker = data_ticker.dropna(subset=["Percent Change"])

# data_SP500['Percent Change'] = data_SP500['Close'].pct_change() * 100
# data_SP500 = data_SP500.dropna(subset=['Percent Change'])

# data_QQQ['Percent Change'] = data_QQQ['Close'].pct_change() * 100
# data_QQQ = data_QQQ.dropna(subset=['Percent Change'])


# data_corr['Percent Change'] = data_corr['Close'].pct_change() * 100
# data_corr = data_corr.dropna(subset=['Percent Change'])


data_industry['Percent Change'] = data_industry['Close'].pct_change() * 100
data_industry = data_industry.dropna(subset=['Percent Change'])

n_days = 10
candlestick_data_10_days = pd.DataFrame()

for i in range(1, n_days + 1):
    candlestick_data_10_days[f"Day_{i} Ticker Open"] = data_ticker["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker High"] = data_ticker["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Low"] = data_ticker["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Adj Close"] = data_ticker["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Volume"] = data_ticker["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Percent Change"] = data_ticker["Percent Change"].shift(i)

    # candlestick_data_10_days[f"Day_{i} SP500 Open"] = data_SP500["Open"].shift(i)
    # candlestick_data_10_days[f"Day_{i} SP500 High"] = data_SP500["High"].shift(i)
    # candlestick_data_10_days[f"Day_{i} SP500 Low"] = data_SP500["Low"].shift(i)
    # candlestick_data_10_days[f"Day_{i} SP500 Adj Close"] = data_SP500["Adj Close"].shift(i)
    # candlestick_data_10_days[f"Day_{i} SP500 Volume"] = data_SP500["Volume"].shift(i)
    # candlestick_data_10_days[f"Day_{i} SP500 Percent Change"] = data_SP500["Percent Change"].shift(i)

    # candlestick_data_10_days[f"Day_{i} QQQ Open"] = data_QQQ["Open"].shift(i)
    # candlestick_data_10_days[f"Day_{i} QQQ High"] = data_QQQ["High"].shift(i)
    # candlestick_data_10_days[f"Day_{i} QQQ Low"] = data_QQQ["Low"].shift(i)
    # candlestick_data_10_days[f"Day_{i} QQQ Adj Close"] = data_QQQ["Adj Close"].shift(i)
    # candlestick_data_10_days[f"Day_{i} QQQ Volume"] = data_QQQ["Volume"].shift(i)
    # candlestick_data_10_days[f"Day_{i} QQQ Percent Change"] = data_QQQ["Percent Change"].shift(i)

    # candlestick_data_10_days[f"Day_{i} corr Open"] = data_corr["Open"].shift(i)
    # candlestick_data_10_days[f"Day_{i} corr High"] = data_corr["High"].shift(i)
    # candlestick_data_10_days[f"Day_{i} corr Low"] = data_corr["Low"].shift(i)
    # candlestick_data_10_days[f"Day_{i} corr Adj Close"] = data_corr["Adj Close"].shift(i)
    # candlestick_data_10_days[f"Day_{i} corr Volume"] = data_corr["Volume"].shift(i)
    # candlestick_data_10_days[f"Day_{i} corr Percent Change"] = data_corr["Percent Change"].shift(i)

    candlestick_data_10_days[f"Day_{i} industry Open"] = data_industry["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry High"] = data_industry["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Low"] = data_industry["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Adj Close"] = data_industry["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Volume"] = data_industry["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Percent Change"] = data_industry["Percent Change"].shift(i)

def categorize_movement(change):
    if change <= -3.0:
        return -2
    elif change <= -1.0:
        return -1
    elif change >= 3.0:
        return 2
    elif change >= 1.0:
        return 1
    else:
        return 0

candlestick_data_10_days["Movement"] = data_ticker["Percent Change"].apply(categorize_movement)
candlestick_data_10_days = candlestick_data_10_days.dropna().reset_index(drop=True)

frequency = candlestick_data_10_days["Movement"].value_counts()
print(frequency)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Movement
#  0    399
#  1    262
# -1    219
#  2    194
# -2    173
# Name: count, dtype: int64
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Volume"] = data_ticker["Volume"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Percent Change"] = data_ticker["Percent Change"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Open"] = data_industry["Open"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry High"] = data_industry["High"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Low"] = data_industry["Low"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:69: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Adj Close"] = data_industry["Adj Close"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Volume"] = data_industry["Volume"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Percent Change"] = data_industry["Percent Change"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Open"] = data_ticker["Open"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker High"] = data_ticker["High"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Low"] = data_ticker["Low"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Adj Close"] = data_ticker["Adj Close"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Volume"] = data_ticker["Volume"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} Ticker Percent Change"] = data_ticker["Percent Change"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Open"] = data_industry["Open"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry High"] = data_industry["High"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Low"] = data_industry["Low"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:69: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Adj Close"] = data_industry["Adj Close"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:70: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Volume"] = data_industry["Volume"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} industry Percent Change"] = data_industry["Percent Change"].shift(i)
# /var/folders/xh/0c12lvfd59g57dbp9dpbncb00000gn/T/ipykernel_66734/313164653.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days["Movement"] = data_ticker["Percent Change"].apply(categorize_movement)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

test_size = 250
train_df = candlestick_data_10_days.iloc[:-test_size]
test_df = candlestick_data_10_days.iloc[-test_size:]

x_train = train_df.drop(columns=["Movement"])
y_train = train_df["Movement"]
x_test = test_df.drop(columns=["Movement"])
y_test = test_df["Movement"]

feature_number = x_train.shape[1]
print(feature_number)

model = RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [100, 250],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2, 5],
    'bootstrap': [True],
    'max_features': ['sqrt', 'log2', 0.5, 0.7, 0.9]
}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid,
                           cv=5, n_jobs=-1, verbose=2)

grid_search.fit(x_train, y_train)
y_pred = grid_search.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# 120
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   7.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   8.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   8.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   7.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   8.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   8.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   7.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   7.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   7.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   8.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   8.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   7.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   7.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   7.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   8.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   7.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   7.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   7.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   7.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   7.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   6.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   6.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   6.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   7.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   6.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   6.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  12.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  12.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  12.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  11.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  11.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  11.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  12.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  11.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  11.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  11.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  11.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  10.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  11.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  11.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  10.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   9.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  10.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   9.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  10.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   8.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   8.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  14.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  13.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  15.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  13.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  14.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  14.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  13.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  13.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  13.7s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  12.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  14.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.0s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  12.9s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  11.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  12.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  11.8s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  12.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time= 4.9min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time= 4.9min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time= 4.9min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time= 5.1min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=   1.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   1.1s
# ...
# [CV] END bootstrap=True, max_depth=20, max_features=0.5, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  10.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  11.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  11.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  10.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  11.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  11.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  10.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  11.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  10.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  11.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  10.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  11.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  10.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  10.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  10.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  10.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   9.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   8.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   9.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   8.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=   9.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   8.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   8.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  14.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  15.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  14.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  14.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  13.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  13.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  14.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  13.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  13.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  13.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  14.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  14.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.7s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  13.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  14.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   5.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  12.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  11.2s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  11.6s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  11.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=2, n_estimators=250; total time=  12.3s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=  10.0s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.8s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.1s
# [CV] END bootstrap=True, max_depth=20, max_features=0.9, min_samples_leaf=5, min_samples_split=5, n_estimators=250; total time=   9.7s
# Accuracy: 0.28

# %%
from sklearn.metrics import confusion_matrix

y_pred = grid_search.predict(x_test)
cm = confusion_matrix(y_test, y_pred)

TP = {}
FP = {}
FN = {}
TN = {}

# Calculate the metrics for each class
for i in range(len(cm)):
    TP[i] = cm[i, i]
    FP[i] = sum(cm[:, i]) - cm[i, i]
    FN[i] = sum(cm[i, :]) - cm[i, i]
    TN[i] = cm.sum() - (FP[i] + FN[i] + TP[i])

# Output the results
for i in range(len(cm)):
    print(f"Class {i}:")
    print(f"TP: {TP[i]}, FP: {FP[i]}, TN: {TN[i]}, FN: {FN[i]}\n")
# Out:
# Class 0:
# TP: 13, FP: 69, TN: 152, FN: 16
#
# Class 1:
# TP: 3, FP: 14, TN: 195, FN: 38
#
# Class 2:
# TP: 51, FP: 87, TN: 71, FN: 41
#
# Class 3:
# TP: 2, FP: 6, TN: 192, FN: 50
#
# Class 4:
# TP: 1, FP: 4, TN: 210, FN: 35
