# %%
import pandas as pd
import yfinance as yf
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Valid Time Periods: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max

data_ticker = yf.download("FCX", period="5y")
data_corr = yf.download("SCCO", period="5y")
data_industry = yf.download("COPX", period="5y")
data_P_index = yf.download("HG=F", period="5y")
data_S_index = yf.download("GC=F", period="5y")


data_ticker["Percent Change"] = data_ticker["Close"].pct_change() * 100
data_ticker = data_ticker.dropna(subset=["Percent Change"])

data_P_index['Percent Change'] = data_P_index['Close'].pct_change() * 100
data_P_index = data_P_index.dropna(subset=['Percent Change'])

data_S_index['Percent Change'] = data_S_index['Close'].pct_change() * 100
data_S_index = data_S_index.dropna(subset=['Percent Change'])


data_corr['Percent Change'] = data_corr['Close'].pct_change() * 100
data_corr = data_corr.dropna(subset=['Percent Change'])


data_industry['Percent Change'] = data_industry['Close'].pct_change() * 100
data_industry = data_industry.dropna(subset=['Percent Change'])

n_days = 10
candlestick_data_10_days = pd.DataFrame()

for i in range(1, n_days + 1):
    candlestick_data_10_days[f"Day_{i} Ticker Open"] = data_ticker["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker High"] = data_ticker["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Low"] = data_ticker["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Adj Close"] = data_ticker["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Volume"] = data_ticker["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} Ticker Percent Change"] = data_ticker["Percent Change"].shift(i)

    candlestick_data_10_days[f"Day_{i} SP500 Open"] = data_P_index["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} SP500 High"] = data_P_index["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} SP500 Low"] = data_P_index["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} SP500 Adj Close"] = data_P_index["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} SP500 Volume"] = data_P_index["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} SP500 Percent Change"] = data_P_index["Percent Change"].shift(i)

    candlestick_data_10_days[f"Day_{i} QQQ Open"] = data_S_index["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} QQQ High"] = data_S_index["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} QQQ Low"] = data_S_index["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} QQQ Adj Close"] = data_S_index["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} QQQ Volume"] = data_S_index["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} QQQ Percent Change"] = data_S_index["Percent Change"].shift(i)

    candlestick_data_10_days[f"Day_{i} corr Open"] = data_corr["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} corr High"] = data_corr["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} corr Low"] = data_corr["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} corr Adj Close"] = data_corr["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} corr Volume"] = data_corr["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} corr Percent Change"] = data_corr["Percent Change"].shift(i)

    candlestick_data_10_days[f"Day_{i} industry Open"] = data_industry["Open"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry High"] = data_industry["High"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Low"] = data_industry["Low"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Adj Close"] = data_industry["Adj Close"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Volume"] = data_industry["Volume"].shift(i)
    candlestick_data_10_days[f"Day_{i} industry Percent Change"] = data_industry["Percent Change"].shift(i)

def categorize_movement(change):
    if change <= -4.0:
        return -2
    elif change <= -1.5:
        return -1
    elif change >= 4.0:
        return 2
    elif change >= 1.5:
        return 1
    else:
        return 0

candlestick_data_10_days["Movement"] = data_ticker["Percent Change"].apply(categorize_movement)
candlestick_data_10_days = candlestick_data_10_days.dropna().reset_index(drop=True)

frequency = candlestick_data_10_days["Movement"].value_counts()
print(frequency)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Movement
#  0    551
# -1    241
#  1    240
#  2    124
# -2     91
# Name: count, dtype: int64
# /var/folders/12/hdw_ls8n7rs0lj0nn0x94wgc0000gn/T/ipykernel_18180/1833490483.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   candlestick_data_10_days[f"Day_{i} SP500 Volume"] = data_P_index["Volume"].shift(i)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

test_size = 200
train_df = candlestick_data_10_days.iloc[:-test_size]
test_df = candlestick_data_10_days.iloc[-test_size:]

x_train = train_df.drop(columns=["Movement"])
y_train = train_df["Movement"]
x_test = test_df.drop(columns=["Movement"])
y_test = test_df["Movement"]

feature_number = x_train.shape[1]
print(feature_number)

model = RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [100, 250],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2, 5],
    'bootstrap': [True],
    'max_features': ['sqrt', 'log2', 0.5, 0.7, 0.9]
}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid,
                           cv=3, n_jobs=-1, verbose=2)

grid_search.fit(x_train, y_train)
y_pred = grid_search.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# 300
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# ...

# %%
from sklearn.metrics import confusion_matrix

y_pred = grid_search.predict(x_test)
cm = confusion_matrix(y_test, y_pred)

TP = {}
FP = {}
FN = {}
TN = {}

# Calculate the metrics for each class
for i in range(len(cm)):
    TP[i] = cm[i, i]
    FP[i] = sum(cm[:, i]) - cm[i, i]
    FN[i] = sum(cm[i, :]) - cm[i, i]
    TN[i] = cm.sum() - (FP[i] + FN[i] + TP[i])

# Output the results
for i in range(len(cm)):
    print(f"Class {i}:")
    print(f"TP: {TP[i]}, FP: {FP[i]}, TN: {TN[i]}, FN: {FN[i]}\n")
# Out:
# Class 0:
# TP: 0, FP: 0, TN: 193, FN: 7
#
# Class 1:
# TP: 0, FP: 1, TN: 164, FN: 35
#
# Class 2:
# TP: 110, FP: 89, TN: 0, FN: 1
#
# Class 3:
# TP: 0, FP: 0, TN: 162, FN: 38
#
# Class 4:
# TP: 0, FP: 0, TN: 191, FN: 9
